# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
features = list()

# getting the features from the file features.txt
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
    
print('No. of features: {}'.format(len(features)))
# Out:
# No. of features: 561

# %% [markdown]
# ## Obtain the train data

# %%
# get the data from txt files and store them into pandas dataframe
x_train = pd.read_csv('UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
x_train['subject'] = pd.read_csv('UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1:'WALKING', 2:'WALKING_UPSTAIRS', 3:'WALKING_DOWNSTAIRS', 4:'SITTING', 5:'STANDING', 6:'LAYING'})

# put all columns in a single dataframe
train = x_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels

train.sample()  # randomly returns a row from the dataframe
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 4710            0.27816           -0.01558          -0.106391
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 4710         -0.997744         -0.989556         -0.981657         -0.997507
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 4710         -0.987863         -0.981792         -0.944886  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 4710                     -0.05931                              0.021568
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 4710                          0.289674                              0.750871
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 4710             -0.983375              0.097937              0.031764
#
#       subject  Activity  ActivityName
# 4710       23         5      STANDING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the test data

# %%
# get the data from txt files and store them into pandas dataframe
x_test = pd.read_csv('UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
x_test['subject'] = pd.read_csv('UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

y_test = pd.read_csv('UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1:'WALKING', 2:'WALKING_UPSTAIRS', 3:'WALKING_DOWNSTAIRS', 4:'SITTING', 5:'STANDING', 6:'LAYING'})

# put all columns in a single dataframe
test = x_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels

test.sample()  # randomly returns a row from the dataframe
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1856           0.270148          -0.032293          -0.094056
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1856         -0.964192         -0.866619         -0.858665         -0.974052
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1856         -0.871808         -0.841075         -0.883151  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1856                     0.008773                              0.142438
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1856                         -0.837935                              0.945515
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1856             -0.840085               0.19211             -0.042909
#
#       subject  Activity  ActivityName
# 1856       18         5      STANDING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Checking for Duplicates

# %%
print('No. of duplicates in train: {}'.format(sum(train.duplicated())))
print('No. of duplicates in test: {}'.format(sum(test.duplicated())))
# Out:
# No. of duplicates in train: 0
# No. of duplicates in test: 0

# %% [markdown]
# ## 2. Checking for Nan/NULL values

# %%
print('No. of Null values in train: {}'.format(train.isnull().values.sum()))
print('No. of Null values in test: {}'.format(test.isnull().values.sum()))
# Out:
# No. of Null values in train: 0
# No. of Null values in test: 0

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
train.to_csv('gaurav.csv')

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=30)
sns.countplot(x='subject', hue='ActivityName', data=train)
plt.show()

# %%
plt.title('No. of datapoints per Activity', fontsize=20)
sns.countplot(x='ActivityName', data=train)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]', '')

train.columns = columns
test.columns = columns

train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## Save this dataframe in a csv file

# %%
train.to_csv('UCI_HAR_DATASET/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_DATASET/csv_files/test.csv', index=False)

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(x_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        x_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(x_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':x_reduced[:,0], 'y':x_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
x_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(x_data = x_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.388s...
# [t-SNE] Computed neighbors for 7352 samples in 67.367s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.049s
# [t-SNE] Iteration 50: error = 124.7543564, gradient norm = 0.0267531 (50 iterations in 19.383s)
# [t-SNE] Iteration 100: error = 107.0806427, gradient norm = 0.0270559 (50 iterations in 7.472s)
# [t-SNE] Iteration 150: error = 100.8749466, gradient norm = 0.0199321 (50 iterations in 5.352s)
# [t-SNE] Iteration 200: error = 97.5600586, gradient norm = 0.0194795 (50 iterations in 4.969s)
# [t-SNE] Iteration 250: error = 95.2890625, gradient norm = 0.0146793 (50 iterations in 5.295s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.289062
# [t-SNE] Iteration 300: error = 4.1185279, gradient norm = 0.0015639 (50 iterations in 3.578s)
# [t-SNE] Iteration 350: error = 3.2095280, gradient norm = 0.0009999 (50 iterations in 5.006s)
# [t-SNE] Iteration 400: error = 2.7803714, gradient norm = 0.0007202 (50 iterations in 5.244s)
# [t-SNE] Iteration 450: error = 2.5159874, gradient norm = 0.0005702 (50 iterations in 4.441s)
# [t-SNE] Iteration 500: error = 2.3322988, gradient norm = 0.0004781 (50 iterations in 4.512s)
# [t-SNE] Iteration 550: error = 2.1946030, gradient norm = 0.0004170 (50 iterations in 5.430s)
# [t-SNE] Iteration 600: error = 2.0855696, gradient norm = 0.0003724 (50 iterations in 5.265s)
# [t-SNE] Iteration 650: error = 1.9960730, gradient norm = 0.0003317 (50 iterations in 4.593s)
# [t-SNE] Iteration 700: error = 1.9204260, gradient norm = 0.0003016 (50 iterations in 4.726s)
# [t-SNE] Iteration 750: error = 1.8553530, gradient norm = 0.0002794 (50 iterations in 4.100s)
# [t-SNE] Iteration 800: error = 1.7990716, gradient norm = 0.0002583 (50 iterations in 4.643s)
# [t-SNE] Iteration 850: error = 1.7492085, gradient norm = 0.0002376 (50 iterations in 4.572s)
# [t-SNE] Iteration 900: error = 1.7046528, gradient norm = 0.0002247 (50 iterations in 4.534s)
# [t-SNE] Iteration 950: error = 1.6644694, gradient norm = 0.0002134 (50 iterations in 4.599s)
# [t-SNE] Iteration 1000: error = 1.6282617, gradient norm = 0.0001974 (50 iterations in 4.499s)
# [t-SNE] KL divergence after 1000 iterations: 1.628262
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.392s...
# [t-SNE] Computed neighbors for 7352 samples in 68.604s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.130s
# [t-SNE] Iteration 50: error = 114.0477219, gradient norm = 0.0238855 (50 iterations in 9.263s)
# [t-SNE] Iteration 100: error = 97.5213699, gradient norm = 0.0179342 (50 iterations in 5.073s)
# [t-SNE] Iteration 150: error = 93.1713715, gradient norm = 0.0095326 (50 iterations in 4.419s)
# [t-SNE] Iteration 200: error = 91.2201309, gradient norm = 0.0064469 (50 iterations in 4.285s)
# [t-SNE] Iteration 250: error = 90.0476456, gradient norm = 0.0058446 (50 iterations in 3.989s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.047646
# [t-SNE] Iteration 300: error = 3.5739520, gradient norm = 0.0014632 (50 iterations in 3.995s)
# [t-SNE] Iteration 350: error = 2.8129981, gradient norm = 0.0007526 (50 iterations in 3.855s)
# [t-SNE] Iteration 400: error = 2.4316108, gradient norm = 0.0005253 (50 iterations in 4.097s)
# [t-SNE] Iteration 450: error = 2.2131522, gradient norm = 0.0004039 (50 iterations in 4.491s)
# [t-SNE] Iteration 500: error = 2.0681291, gradient norm = 0.0003319 (50 iterations in 3.625s)
# [t-SNE] Iteration 550: error = 1.9628046, gradient norm = 0.0002825 (50 iterations in 4.086s)
# [t-SNE] Iteration 600: error = 1.8816440, gradient norm = 0.0002469 (50 iterations in 4.664s)
# [t-SNE] Iteration 650: error = 1.8163937, gradient norm = 0.0002202 (50 iterations in 4.461s)
# [t-SNE] Iteration 700: error = 1.7627702, gradient norm = 0.0001962 (50 iterations in 4.994s)
# [t-SNE] Iteration 750: error = 1.7172767, gradient norm = 0.0001796 (50 iterations in 4.103s)
# [t-SNE] Iteration 800: error = 1.6783892, gradient norm = 0.0001642 (50 iterations in 3.927s)
# [t-SNE] Iteration 850: error = 1.6446102, gradient norm = 0.0001526 (50 iterations in 4.244s)
# [t-SNE] Iteration 900: error = 1.6148183, gradient norm = 0.0001404 (50 iterations in 4.399s)
# [t-SNE] Iteration 950: error = 1.5885730, gradient norm = 0.0001330 (50 iterations in 4.278s)
# [t-SNE] Iteration 1000: error = 1.5651038, gradient norm = 0.0001239 (50 iterations in 4.277s)
# [t-SNE] KL divergence after 1000 iterations: 1.565104
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.621s...
# [t-SNE] Computed neighbors for 7352 samples in 71.877s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.149s
# [t-SNE] Iteration 50: error = 105.7465210, gradient norm = 0.0206004 (50 iterations in 8.410s)
# [t-SNE] Iteration 100: error = 90.6384201, gradient norm = 0.0125674 (50 iterations in 5.253s)
# [t-SNE] Iteration 150: error = 87.4748077, gradient norm = 0.0060703 (50 iterations in 4.967s)
# [t-SNE] Iteration 200: error = 86.2024307, gradient norm = 0.0034768 (50 iterations in 4.950s)
# [t-SNE] Iteration 250: error = 85.4880676, gradient norm = 0.0030826 (50 iterations in 5.050s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.488068
# [t-SNE] Iteration 300: error = 3.1415739, gradient norm = 0.0013998 (50 iterations in 5.069s)
# [t-SNE] Iteration 350: error = 2.4971311, gradient norm = 0.0006508 (50 iterations in 4.580s)
# [t-SNE] Iteration 400: error = 2.1760352, gradient norm = 0.0004288 (50 iterations in 4.843s)
# [t-SNE] Iteration 450: error = 1.9912281, gradient norm = 0.0003143 (50 iterations in 4.877s)
# [t-SNE] Iteration 500: error = 1.8726579, gradient norm = 0.0002518 (50 iterations in 4.990s)
# [t-SNE] Iteration 550: error = 1.7887484, gradient norm = 0.0002127 (50 iterations in 4.590s)
# [t-SNE] Iteration 600: error = 1.7258309, gradient norm = 0.0001820 (50 iterations in 4.422s)
# [t-SNE] Iteration 650: error = 1.6763741, gradient norm = 0.0001624 (50 iterations in 4.451s)
# [t-SNE] Iteration 700: error = 1.6366931, gradient norm = 0.0001435 (50 iterations in 4.177s)
# [t-SNE] Iteration 750: error = 1.6039007, gradient norm = 0.0001308 (50 iterations in 4.451s)
# [t-SNE] Iteration 800: error = 1.5761602, gradient norm = 0.0001198 (50 iterations in 4.651s)
# [t-SNE] Iteration 850: error = 1.5528572, gradient norm = 0.0001144 (50 iterations in 4.418s)
# [t-SNE] Iteration 900: error = 1.5330569, gradient norm = 0.0001052 (50 iterations in 4.665s)
# [t-SNE] Iteration 950: error = 1.5158786, gradient norm = 0.0000987 (50 iterations in 4.494s)
# [t-SNE] Iteration 1000: error = 1.5010563, gradient norm = 0.0000931 (50 iterations in 4.730s)
# [t-SNE] KL divergence after 1000 iterations: 1.501056
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.392s...
# [t-SNE] Computed neighbors for 7352 samples in 75.216s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.292s
# [t-SNE] Iteration 50: error = 97.5027390, gradient norm = 0.0177799 (50 iterations in 12.734s)
# [t-SNE] Iteration 100: error = 84.0726929, gradient norm = 0.0070783 (50 iterations in 6.466s)
# [t-SNE] Iteration 150: error = 81.9093781, gradient norm = 0.0034581 (50 iterations in 6.491s)
# [t-SNE] Iteration 200: error = 81.1684113, gradient norm = 0.0025570 (50 iterations in 5.829s)
# [t-SNE] Iteration 250: error = 80.7822418, gradient norm = 0.0019349 (50 iterations in 6.901s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.782242
# [t-SNE] Iteration 300: error = 2.6954014, gradient norm = 0.0013046 (50 iterations in 5.284s)
# [t-SNE] Iteration 350: error = 2.1640062, gradient norm = 0.0005771 (50 iterations in 5.059s)
# [t-SNE] Iteration 400: error = 1.9152673, gradient norm = 0.0003495 (50 iterations in 4.809s)
# [t-SNE] Iteration 450: error = 1.7692401, gradient norm = 0.0002487 (50 iterations in 4.422s)
# [t-SNE] Iteration 500: error = 1.6753638, gradient norm = 0.0001922 (50 iterations in 4.017s)
# [t-SNE] Iteration 550: error = 1.6112576, gradient norm = 0.0001589 (50 iterations in 4.886s)
# [t-SNE] Iteration 600: error = 1.5644624, gradient norm = 0.0001357 (50 iterations in 4.835s)
# [t-SNE] Iteration 650: error = 1.5290798, gradient norm = 0.0001167 (50 iterations in 4.738s)
# [t-SNE] Iteration 700: error = 1.5017204, gradient norm = 0.0001040 (50 iterations in 4.723s)
# [t-SNE] Iteration 750: error = 1.4797741, gradient norm = 0.0000945 (50 iterations in 5.081s)
# [t-SNE] Iteration 800: error = 1.4618922, gradient norm = 0.0000890 (50 iterations in 4.812s)
# [t-SNE] Iteration 850: error = 1.4475511, gradient norm = 0.0000824 (50 iterations in 5.196s)
# [t-SNE] Iteration 900: error = 1.4357331, gradient norm = 0.0000830 (50 iterations in 4.749s)
# [t-SNE] Iteration 950: error = 1.4264762, gradient norm = 0.0000765 (50 iterations in 5.021s)
# [t-SNE] Iteration 1000: error = 1.4183602, gradient norm = 0.0000746 (50 iterations in 4.733s)
# [t-SNE] KL divergence after 1000 iterations: 1.418360
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.405s...
# [t-SNE] Computed neighbors for 7352 samples in 67.624s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.713s
# [t-SNE] Iteration 50: error = 86.5809860, gradient norm = 0.0198619 (50 iterations in 10.487s)
# [t-SNE] Iteration 100: error = 76.1361465, gradient norm = 0.0046763 (50 iterations in 8.756s)
# [t-SNE] Iteration 150: error = 74.9811935, gradient norm = 0.0025573 (50 iterations in 7.198s)
# [t-SNE] Iteration 200: error = 74.4145737, gradient norm = 0.0015471 (50 iterations in 8.278s)
# [t-SNE] Iteration 250: error = 74.1433792, gradient norm = 0.0011740 (50 iterations in 8.526s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.143379
# [t-SNE] Iteration 300: error = 2.1711142, gradient norm = 0.0011880 (50 iterations in 7.226s)
# [t-SNE] Iteration 350: error = 1.7690698, gradient norm = 0.0004972 (50 iterations in 5.947s)
# [t-SNE] Iteration 400: error = 1.5970385, gradient norm = 0.0002866 (50 iterations in 6.919s)
# [t-SNE] Iteration 450: error = 1.5013515, gradient norm = 0.0001934 (50 iterations in 6.757s)
# [t-SNE] Iteration 500: error = 1.4402488, gradient norm = 0.0001456 (50 iterations in 6.256s)
# [t-SNE] Iteration 550: error = 1.3982801, gradient norm = 0.0001165 (50 iterations in 5.969s)
# [t-SNE] Iteration 600: error = 1.3685186, gradient norm = 0.0000979 (50 iterations in 5.790s)
# [t-SNE] Iteration 650: error = 1.3468760, gradient norm = 0.0000845 (50 iterations in 6.770s)
# [t-SNE] Iteration 700: error = 1.3308514, gradient norm = 0.0000755 (50 iterations in 6.213s)
# [t-SNE] Iteration 750: error = 1.3187019, gradient norm = 0.0000709 (50 iterations in 4.505s)
# [t-SNE] Iteration 800: error = 1.3095897, gradient norm = 0.0000666 (50 iterations in 7.324s)
# [t-SNE] Iteration 850: error = 1.3024557, gradient norm = 0.0000630 (50 iterations in 5.901s)
# [t-SNE] Iteration 900: error = 1.2963468, gradient norm = 0.0000583 (50 iterations in 6.167s)
# [t-SNE] Iteration 950: error = 1.2911690, gradient norm = 0.0000555 (50 iterations in 6.085s)
# [t-SNE] Iteration 1000: error = 1.2866576, gradient norm = 0.0000529 (50 iterations in 6.920s)
# [t-SNE] KL divergence after 1000 iterations: 1.286658
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
